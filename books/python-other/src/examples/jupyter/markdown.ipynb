# %% [markdown]
# # Main title
#
# ## Secondary title
#
# ### Tertiary title
#
# Plain text where
# rows are merged together
#      and even indentation does not matter.
#
# Empty rows separate paragraphs.
#
# We can have **bold** test an __italics__
# We can insert a `monospace` snippet for `code` or a whole block written verbatim. Including indentation. You can also indicate the (programming) language you are using and you'll get syntax highlighting. We can even link to the article about [Markdown in Jupyter Notebook](https://jupyter-notebook.readthedocs.io/en/latest/examples/Notebook/Working%20With%20Markdown%20Cells.html)
#
# You can quote some text by prefixing with a greater than sign:
#
# > Project Jupyter's name is a reference to the three core programming languages supported by Jupyter,
# > which are Julia, Python and R,
# > and also a homage to Galileo's notebooks recording the discovery of the moons of Jupiter.
# > [Wikipedia](https://en.wikipedia.org/wiki/Project_Jupyter)
#
#
# ![Jupyter logo](375px-Jupyter_logo.svg.png)
#
# ```python
# name = "Jupyter Notebook"
# print(name)
# if "Python" in name:
#     print("found")
# ```
#
# Horizontal line:
# ---
#
# ---
#
#
#
# Unordered list
# ----
#
# * Apple
# * Banana
# * Peach
#
# Ordered list
# ---
#
# 1. First
# 1. Second
# 1. Third
#
#
# Table
# ---
#
# | Planet name | Distance (AU) | Mass  |
# | :------------| -------------: | ----  |
# | Mercury     | 0.4           | 0.055 |
# | Venus       | 0.7           | 0.815 |
# | **Earth**   | 1             | 1     |
# | Mars        | 1.5           | 0.107 |
# | Ceres       | 2.77          | 0.00015 |
# | Jupiter     | 5.2           | 318   |
# | Saturn      | 9.5           | 95    |
# | Uranus      | 19.6          | 14    |
# | Neptune     | 30            | 17    |
# | Pluto       | 39            | 0.00218 |
# | Charon      | 39            | 0.000254 |
#
# * Note the alignment using `:`.
