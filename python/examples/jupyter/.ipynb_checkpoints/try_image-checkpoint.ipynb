# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
#import matplotlib.image as mpimg

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

mat = np.random.rand(300, 500)
plt.imshow(mat)
