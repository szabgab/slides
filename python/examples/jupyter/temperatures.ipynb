# %%
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv('temperatures.csv')

# %%
df.head()

# %%
plot = sns.relplot(
    x = "Time",
    y = "Tel Aviv",
    #kind = "line",
    data = df)
